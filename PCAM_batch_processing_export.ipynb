# %% [markdown]
# <a href="https://colab.research.google.com/github/wlr2678/ChangE_4_data_playground/blob/master/first_glance_own_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install a pip package in the current Jupyter kernel
import sys
pip install pds4_tools
pip install matplotlib
pip install numpy
pip install Pillow
pip install colour-science
pip install colour-demosaicing

# %%
# Initialization
from pds4_tools import pds4_read       # to read and inspect the data and metadata
import matplotlib.pyplot as plt        # for plotting
import matplotlib
import numpy as np
from PIL import Image

import cv2 as cv # HDR tonemapping trial

# for plotting in Jupyter notebooks
# %matplotlib notebook
# for plotting in Google Colab, inline with the cell outputs
# %matplotlib inline

from skimage import exposure
from skimage import data, img_as_float
import colour
from colour.plotting import *
import glob, os # for batch reading, processing and exporting in directories

from colour_demosaicing import (
    demosaicing_CFA_Bayer_bilinear,
    demosaicing_CFA_Bayer_Malvar2004,
    demosaicing_CFA_Bayer_Menon2007,
    mosaicing_CFA_Bayer)

cctf_encoding = colour.cctf_encoding
_ = colour.utilities.filter_warnings()
# colour.utilities.describe_environment();

def read_pds(path):
    data = pds4_read(path, quiet=True)
    img = np.array(data[0].data)
    img = img_as_float(img)
    return img

def debayer_img(img, CFArr='RGGB'):
    debayered = cctf_encoding(demosaicing_CFA_Bayer_bilinear(img, CFArr))
    return debayered

def stretch_img(img, percent=0.5):
    # cf https://www.harrisgeospatial.com/docs/BackgroundStretchTypes.html
    # Adapts for different percentages
    p2, p98 = np.percentile(img, (0+percent, 100-percent))
    img = exposure.rescale_intensity(img, in_range=(p2, p98))
    return img

def check_type(p): # Check PCAM image type
    ty = p.split('_')[2].split('-')[1]
    return ty

def plot_img_and_hist(image, ty='Q', size=10,  hist=True, bins=128): # ty indicates the type of the data product
    """Plot an image along with its histogram.
    """
    if hist:
        fig, axes = plt.subplots(2,1, figsize=(size,size), gridspec_kw={'height_ratios': [3, 1]})
        ax_img, ax_hist = axes
    else:
        fig, ax_img = plt.subplots(figsize=(size,size))

    # Display image
    ax_img.imshow(image, cmap='gray')
    # Without axes on image
    ax_img.set_axis_off()

    if hist:
        # Display histogram
        if ty == 'Q': # Panchromatic
          ax_hist.hist(image.ravel(), bins=bins, histtype='step', color='black')
        elif ty == 'C': # Colour
          ax_hist.hist(image[:,:,0].ravel(), bins=bins, histtype='step', color='red')
          ax_hist.hist(image[:,:,1].ravel(), bins=bins, histtype='step', color='green')
          ax_hist.hist(image[:,:,2].ravel(), bins=bins, histtype='step', color='blue')
        else: # Unknown type
          print('Image data type not recognized')
          pass

        ax_hist.ticklabel_format(axis='y', style='scientific', scilimits=(0, 0))
        ax_hist.set_xlabel('Pixel intensity')
        ax_hist.set_xlim(0, 1)
        ax_hist.set_yticks([])
    
def export_img(name, img):
    pil_img = Image.fromarray(np.clip(img*255, 0, 255).astype('uint8'))
    pil_img.save(name)

def preview_save(img, ty, size=10, hist=False):
    print('Generating preview...')
    plot_img_and_hist(img, ty, size, hist)
    plt.show()
    print('Saving image...')
    export_img('{}.png'.format(p), img)

def truncate(filename): # Trim filenames for less cluttered message printouts # Choose to not truncate but retain the original file names
    trimmed_name = filename.split('_')[2][0:-4] + '_' + filename.split('_')[5]
    return trimmed_name

# %%
# Processing and Export
directory = 'C:/Users/Darren Wu/Desktop/SpaceInfos/2022/CE5/PCAM/0002'
os.chdir(directory)
p = []
for filename in glob.glob('*.2BL'):
    if (filename.removesuffix('.2BL') + '.png') not in glob.glob('*.png'):
        p.append(filename)
print('File list loaded.')
#print(p)

for filename in p:
    img = read_pds(filename)
    ty = check_type(filename)

    if ty == 'I':
        ty = 'C' # Chang'e 5 PCAM images are always in colour 

    print('Processing and exporting file ({index}) {name}'.format(index = p.index(filename)+1, name = filename.removesuffix('.2BL')), end='\n')

    if ty == 'C':
        img = debayer_img(img)
        img = img.astype('float32')
        #tonemap1 = cv.createTonemap(gamma=1)
        tonemap1 = cv.createTonemapMantiuk(gamma=2, scale=1, saturation=2)
        #tonemap1 = cv.createTonemapReinhard(gamma=0.7, intensity=0, light_adapt=1, color_adapt=0)
        img = tonemap1.process(img)

    #img = stretch_img(img)

    #print('Generating preview...')
    #plot_img_and_hist(img, ty, 10, True)
    #plt.show()
    export_img('{}.png'.format(filename.removesuffix('.2BL')), img)
    print('DONE')
# Out:
# File list loaded.
# Processing and exporting file (1) CE5-L_GRAS_PCAML-I-008_SCI_N_20201202151700_20201202151700_0002_A
# DONE
# Processing and exporting file (2) CE5-L_GRAS_PCAML-I-009_SCI_N_20201202153803_20201202153803_0002_A
# DONE
# Processing and exporting file (3) CE5-L_GRAS_PCAML-I-010_SCI_N_20201202153815_20201202153815_0002_A
# DONE
# Processing and exporting file (4) CE5-L_GRAS_PCAML-I-011_SCI_N_20201202153827_20201202153827_0002_A
# DONE
# Processing and exporting file (5) CE5-L_GRAS_PCAML-I-012_SCI_N_20201202153839_20201202153839_0002_A
# DONE
# Processing and exporting file (6) CE5-L_GRAS_PCAML-I-013_SCI_N_20201202153851_20201202153851_0002_A
# DONE
# Processing and exporting file (7) CE5-L_GRAS_PCAML-I-014_SCI_N_20201202153903_20201202153903_0002_A
# DONE
# Processing and exporting file (8) CE5-L_GRAS_PCAML-I-015_SCI_N_20201202153915_20201202153915_0002_A
# DONE
# Processing and exporting file (9) CE5-L_GRAS_PCAML-I-016_SCI_N_20201202153927_20201202153927_0002_A
# DONE
# Processing and exporting file (10) CE5-L_GRAS_PCAML-I-017_SCI_N_20201202153939_20201202153939_0002_A
# DONE
# Processing and exporting file (11) CE5-L_GRAS_PCAML-I-018_SCI_N_20201202153951_20201202153951_0002_A
# DONE
# Processing and exporting file (12) CE5-L_GRAS_PCAML-I-019_SCI_N_20201202154003_20201202154003_0002_A
# DONE
# Processing and exporting file (13) CE5-L_GRAS_PCAML-I-020_SCI_N_20201202154015_20201202154015_0002_A
# DONE
# Processing and exporting file (14) CE5-L_GRAS_PCAML-I-021_SCI_N_20201202154027_20201202154027_0002_A
# DONE
# Processing and exporting file (15) CE5-L_GRAS_PCAML-I-022_SCI_N_20201202154039_20201202154039_0002_A
# DONE
# Processing and exporting file (16) CE5-L_GRAS_PCAML-I-023_SCI_N_20201202154051_20201202154051_0002_A
# DONE
# Processing and exporting file (17) CE5-L_GRAS_PCAML-I-024_SCI_N_20201202154103_20201202154103_0002_A
# DONE
# Processing and exporting file (18) CE5-L_GRAS_PCAML-I-025_SCI_N_20201202154115_20201202154115_0002_A
# DONE
# Processing and exporting file (19) CE5-L_GRAS_PCAML-I-026_SCI_N_20201202154127_20201202154127_0002_A
# DONE
# Processing and exporting file (20) CE5-L_GRAS_PCAML-I-027_SCI_N_20201202154139_20201202154139_0002_A
# DONE
# Processing and exporting file (21) CE5-L_GRAS_PCAML-I-028_SCI_N_20201202154151_20201202154151_0002_A
# DONE
# Processing and exporting file (22) CE5-L_GRAS_PCAML-I-029_SCI_N_20201202154203_20201202154203_0002_A
# DONE
# Processing and exporting file (23) CE5-L_GRAS_PCAML-I-030_SCI_N_20201202154215_20201202154215_0002_A
# DONE
# Processing and exporting file (24) CE5-L_GRAS_PCAML-I-031_SCI_N_20201202154227_20201202154227_0002_A
# DONE
# Processing and exporting file (25) CE5-L_GRAS_PCAML-I-032_SCI_N_20201202154239_20201202154239_0002_A
# DONE
# Processing and exporting file (26) CE5-L_GRAS_PCAML-I-033_SCI_N_20201202154251_20201202154251_0002_A
# DONE
# Processing and exporting file (27) CE5-L_GRAS_PCAML-I-034_SCI_N_20201202154303_20201202154303_0002_A
# DONE
# Processing and exporting file (28) CE5-L_GRAS_PCAML-I-035_SCI_N_20201202154315_20201202154315_0002_A
# DONE
# Processing and exporting file (29) CE5-L_GRAS_PCAML-I-036_SCI_N_20201202154327_20201202154327_0002_A
# DONE
# Processing and exporting file (30) CE5-L_GRAS_PCAML-I-037_SCI_N_20201202154339_20201202154339_0002_A
# DONE
# Processing and exporting file (31) CE5-L_GRAS_PCAML-I-038_SCI_N_20201202154351_20201202154351_0002_A
# DONE
# Processing and exporting file (32) CE5-L_GRAS_PCAML-I-039_SCI_N_20201202154403_20201202154403_0002_A
# DONE
# Processing and exporting file (33) CE5-L_GRAS_PCAML-I-040_SCI_N_20201202154415_20201202154415_0002_A
# DONE
# Processing and exporting file (34) CE5-L_GRAS_PCAML-I-041_SCI_N_20201202154427_20201202154427_0002_A
# DONE
# Processing and exporting file (35) CE5-L_GRAS_PCAML-I-042_SCI_N_20201202154439_20201202154439_0002_A
# DONE
# Processing and exporting file (36) CE5-L_GRAS_PCAML-I-043_SCI_N_20201202154451_20201202154451_0002_A
# DONE
# Processing and exporting file (37) CE5-L_GRAS_PCAML-I-044_SCI_N_20201202154503_20201202154503_0002_A
# DONE
# Processing and exporting file (38) CE5-L_GRAS_PCAML-I-045_SCI_N_20201202154515_20201202154515_0002_A
# DONE
# Processing and exporting file (39) CE5-L_GRAS_PCAML-I-046_SCI_N_20201202154527_20201202154527_0002_A
# DONE
# Processing and exporting file (40) CE5-L_GRAS_PCAML-I-047_SCI_N_20201202154539_20201202154539_0002_A
# DONE
# Processing and exporting file (41) CE5-L_GRAS_PCAML-I-048_SCI_N_20201202154551_20201202154551_0002_A
# DONE
# Processing and exporting file (42) CE5-L_GRAS_PCAML-I-049_SCI_N_20201202154603_20201202154603_0002_A
# DONE
# Processing and exporting file (43) CE5-L_GRAS_PCAML-I-050_SCI_N_20201202154615_20201202154615_0002_A
# DONE
# Processing and exporting file (44) CE5-L_GRAS_PCAML-I-051_SCI_N_20201202154627_20201202154627_0002_A
# DONE
# Processing and exporting file (45) CE5-L_GRAS_PCAML-I-052_SCI_N_20201202154639_20201202154639_0002_A
# DONE
# Processing and exporting file (46) CE5-L_GRAS_PCAML-I-053_SCI_N_20201202154651_20201202154651_0002_A
# DONE
# Processing and exporting file (47) CE5-L_GRAS_PCAML-I-054_SCI_N_20201202154703_20201202154703_0002_A
# DONE
# Processing and exporting file (48) CE5-L_GRAS_PCAML-I-055_SCI_N_20201202154715_20201202154715_0002_A
# DONE
# Processing and exporting file (49) CE5-L_GRAS_PCAML-I-056_SCI_N_20201202154727_20201202154727_0002_A
# DONE
# Processing and exporting file (50) CE5-L_GRAS_PCAML-I-057_SCI_N_20201202154739_20201202154739_0002_A
# DONE
# Processing and exporting file (51) CE5-L_GRAS_PCAML-I-058_SCI_N_20201202154751_20201202154751_0002_A
# DONE
# Processing and exporting file (52) CE5-L_GRAS_PCAML-I-059_SCI_N_20201202154803_20201202154803_0002_A
# DONE
# Processing and exporting file (53) CE5-L_GRAS_PCAML-I-060_SCI_N_20201202154815_20201202154815_0002_A
# DONE
# Processing and exporting file (54) CE5-L_GRAS_PCAML-I-061_SCI_N_20201202154827_20201202154827_0002_A
# DONE
# Processing and exporting file (55) CE5-L_GRAS_PCAML-I-062_SCI_N_20201202154839_20201202154839_0002_A
# DONE
# Processing and exporting file (56) CE5-L_GRAS_PCAML-I-063_SCI_N_20201202154851_20201202154851_0002_A
# DONE
# Processing and exporting file (57) CE5-L_GRAS_PCAML-I-064_SCI_N_20201202154903_20201202154903_0002_A
# DONE
# Processing and exporting file (58) CE5-L_GRAS_PCAML-I-065_SCI_N_20201202154915_20201202154915_0002_A
# DONE
# Processing and exporting file (59) CE5-L_GRAS_PCAML-I-066_SCI_N_20201202154927_20201202154927_0002_A
# DONE
# Processing and exporting file (60) CE5-L_GRAS_PCAML-I-067_SCI_N_20201202154939_20201202154939_0002_A
# DONE
# Processing and exporting file (61) CE5-L_GRAS_PCAML-I-068_SCI_N_20201202154951_20201202154951_0002_A
# DONE
# Processing and exporting file (62) CE5-L_GRAS_PCAML-I-069_SCI_N_20201202155003_20201202155003_0002_A
# DONE
# Processing and exporting file (63) CE5-L_GRAS_PCAML-I-070_SCI_N_20201202155015_20201202155015_0002_A
# DONE
# Processing and exporting file (64) CE5-L_GRAS_PCAML-I-071_SCI_N_20201202155027_20201202155027_0002_A
# DONE
# Processing and exporting file (65) CE5-L_GRAS_PCAML-I-072_SCI_N_20201202155039_20201202155039_0002_A
# DONE
# Processing and exporting file (66) CE5-L_GRAS_PCAML-I-073_SCI_N_20201202155051_20201202155051_0002_A
# DONE
# Processing and exporting file (67) CE5-L_GRAS_PCAML-I-074_SCI_N_20201202155103_20201202155103_0002_A
# DONE
# Processing and exporting file (68) CE5-L_GRAS_PCAML-I-075_SCI_N_20201202155115_20201202155115_0002_A
# DONE
# Processing and exporting file (69) CE5-L_GRAS_PCAML-I-076_SCI_N_20201202155127_20201202155127_0002_A
# DONE
# Processing and exporting file (70) CE5-L_GRAS_PCAML-I-077_SCI_N_20201202155139_20201202155139_0002_A
# DONE
# Processing and exporting file (71) CE5-L_GRAS_PCAML-I-078_SCI_N_20201202155151_20201202155151_0002_A
# DONE
# Processing and exporting file (72) CE5-L_GRAS_PCAML-I-079_SCI_N_20201202155203_20201202155203_0002_A
# DONE
# Processing and exporting file (73) CE5-L_GRAS_PCAML-I-080_SCI_N_20201202155215_20201202155215_0002_A
# DONE
# Processing and exporting file (74) CE5-L_GRAS_PCAML-I-081_SCI_N_20201202155227_20201202155227_0002_A
# DONE
# Processing and exporting file (75) CE5-L_GRAS_PCAML-I-082_SCI_N_20201202155239_20201202155239_0002_A
# DONE
# Processing and exporting file (76) CE5-L_GRAS_PCAML-I-083_SCI_N_20201202155251_20201202155251_0002_A
# DONE
# Processing and exporting file (77) CE5-L_GRAS_PCAML-I-084_SCI_N_20201202155303_20201202155303_0002_A
# DONE
# Processing and exporting file (78) CE5-L_GRAS_PCAML-I-085_SCI_N_20201202155315_20201202155315_0002_A
# DONE
# Processing and exporting file (79) CE5-L_GRAS_PCAML-I-086_SCI_N_20201202155327_20201202155327_0002_A
# DONE
# Processing and exporting file (80) CE5-L_GRAS_PCAML-I-087_SCI_N_20201202155339_20201202155339_0002_A
# DONE
# Processing and exporting file (81) CE5-L_GRAS_PCAML-I-088_SCI_N_20201202155351_20201202155351_0002_A
# DONE
# Processing and exporting file (82) CE5-L_GRAS_PCAML-I-089_SCI_N_20201202155403_20201202155403_0002_A
# DONE
# Processing and exporting file (83) CE5-L_GRAS_PCAML-I-090_SCI_N_20201202155415_20201202155415_0002_A
# DONE
# Processing and exporting file (84) CE5-L_GRAS_PCAML-I-091_SCI_N_20201202155427_20201202155427_0002_A
# DONE
# Processing and exporting file (85) CE5-L_GRAS_PCAML-I-092_SCI_N_20201202155439_20201202155439_0002_A
# DONE
# Processing and exporting file (86) CE5-L_GRAS_PCAML-I-093_SCI_N_20201202155451_20201202155451_0002_A
# DONE
# Processing and exporting file (87) CE5-L_GRAS_PCAML-I-094_SCI_N_20201202155503_20201202155503_0002_A
# DONE
# Processing and exporting file (88) CE5-L_GRAS_PCAML-I-095_SCI_N_20201202155515_20201202155515_0002_A
# DONE
# Processing and exporting file (89) CE5-L_GRAS_PCAML-I-096_SCI_N_20201202155527_20201202155527_0002_A
# DONE
# Processing and exporting file (90) CE5-L_GRAS_PCAML-I-097_SCI_N_20201202155539_20201202155539_0002_A
# DONE
# Processing and exporting file (91) CE5-L_GRAS_PCAML-I-098_SCI_N_20201202155551_20201202155551_0002_A
# DONE
# Processing and exporting file (92) CE5-L_GRAS_PCAML-I-099_SCI_N_20201202155603_20201202155603_0002_A
# DONE
# Processing and exporting file (93) CE5-L_GRAS_PCAML-I-100_SCI_N_20201202155615_20201202155615_0002_A
# DONE
# Processing and exporting file (94) CE5-L_GRAS_PCAML-I-101_SCI_N_20201202155627_20201202155627_0002_A
# DONE
# Processing and exporting file (95) CE5-L_GRAS_PCAML-I-102_SCI_N_20201202155639_20201202155639_0002_A
# DONE
# Processing and exporting file (96) CE5-L_GRAS_PCAML-I-103_SCI_N_20201202155651_20201202155651_0002_A
# DONE
# Processing and exporting file (97) CE5-L_GRAS_PCAML-I-104_SCI_N_20201202155703_20201202155703_0002_A
# DONE
# Processing and exporting file (98) CE5-L_GRAS_PCAML-I-105_SCI_N_20201202155715_20201202155715_0002_A
# DONE
# Processing and exporting file (99) CE5-L_GRAS_PCAML-I-106_SCI_N_20201202155727_20201202155727_0002_A
# DONE
# Processing and exporting file (100) CE5-L_GRAS_PCAML-I-107_SCI_N_20201202155739_20201202155739_0002_A
# DONE
# Processing and exporting file (101) CE5-L_GRAS_PCAML-I-108_SCI_N_20201202155751_20201202155751_0002_A
# DONE
# Processing and exporting file (102) CE5-L_GRAS_PCAML-I-109_SCI_N_20201202155803_20201202155803_0002_A
# DONE
# Processing and exporting file (103) CE5-L_GRAS_PCAML-I-110_SCI_N_20201202155815_20201202155815_0002_A
# DONE
# Processing and exporting file (104) CE5-L_GRAS_PCAML-I-111_SCI_N_20201202155827_20201202155827_0002_A
# DONE
# Processing and exporting file (105) CE5-L_GRAS_PCAML-I-112_SCI_N_20201202155839_20201202155839_0002_A
# DONE
# Processing and exporting file (106) CE5-L_GRAS_PCAML-I-113_SCI_N_20201202155851_20201202155851_0002_A
# DONE
# Processing and exporting file (107) CE5-L_GRAS_PCAML-I-114_SCI_N_20201202155903_20201202155903_0002_A
# DONE
# Processing and exporting file (108) CE5-L_GRAS_PCAML-I-115_SCI_N_20201202155915_20201202155915_0002_A
# DONE
# Processing and exporting file (109) CE5-L_GRAS_PCAML-I-116_SCI_N_20201202155927_20201202155927_0002_A
# DONE
# Processing and exporting file (110) CE5-L_GRAS_PCAML-I-117_SCI_N_20201202155939_20201202155939_0002_A
# DONE
# Processing and exporting file (111) CE5-L_GRAS_PCAML-I-118_SCI_N_20201202155951_20201202155951_0002_A
# DONE
# Processing and exporting file (112) CE5-L_GRAS_PCAML-I-119_SCI_N_20201202160003_20201202160003_0002_A
# DONE
# Processing and exporting file (113) CE5-L_GRAS_PCAML-I-120_SCI_N_20201202160015_20201202160015_0002_A
# DONE
# Processing and exporting file (114) CE5-L_GRAS_PCAML-I-121_SCI_N_20201202160027_20201202160027_0002_A
# DONE
# Processing and exporting file (115) CE5-L_GRAS_PCAML-I-122_SCI_N_20201202160039_20201202160039_0002_A
# DONE
# Processing and exporting file (116) CE5-L_GRAS_PCAML-I-123_SCI_N_20201202160051_20201202160051_0002_A
# DONE
# Processing and exporting file (117) CE5-L_GRAS_PCAML-I-124_SCI_N_20201202160103_20201202160103_0002_A
# DONE
# Processing and exporting file (118) CE5-L_GRAS_PCAML-I-125_SCI_N_20201202160115_20201202160115_0002_A
# DONE
# Processing and exporting file (119) CE5-L_GRAS_PCAML-I-126_SCI_N_20201202160127_20201202160127_0002_A
# DONE
# Processing and exporting file (120) CE5-L_GRAS_PCAML-I-127_SCI_N_20201202160139_20201202160139_0002_A
# DONE
# Processing and exporting file (121) CE5-L_GRAS_PCAML-I-128_SCI_N_20201202160151_20201202160151_0002_A
# DONE
